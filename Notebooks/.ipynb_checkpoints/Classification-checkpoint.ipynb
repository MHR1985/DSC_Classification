# %% [markdown]
# # 1. Bayes' theorem
# Bayes' theorem says P(A|B)=P(B|A)\*P(A)/P(B)
#
# a)
# 60% of the kids play football, and 36% of the kids play ice hockey. 40% of the kids who play football
# also play ice hockey. What percent of those that play ice hockey also play football?
#
# a = football
# b = hockey
#
# inserting into the bayes theorem we get:

# %%
footballHockey = 0.4
football = 0.6
hockey = 0.36
footballHockey*football/hockey
# Out:
# 0.6666666666666666

# %% [markdown]
# so 66.67 % of the children that play hockey, also play football.
#
# b)
#
# 40% of the kids like music, and 24% of the kids like to dance. Given that 30% of those that like
# music also likes to dance, what percent of those that like to dance also likes music?
#
# a = music
# b = dance
#
# inserting into the bayes theorem we get:

# %%
music = 0.4
dance = 0.24
danceMusic = 0.3

danceMusic*music/dance
# Out:
# 0.5

# %% [markdown]
# so 50% of the children that likes to dance also likes music.
#
# c)
#
# In a factory, machine X produces 60% of the daily output and machine Y produces 40% of the daily
# output.
# 2% of machine X’s output is defective, and 1.5% of machine Y’s output is defective.
# One day, an item is inspected at random, and found to be defective. What is the probability that it
# was produced by machine X?
#
# Initial probability of product being machine x = 60% = 0.6
# Initial probability of product being machine y = 40% = 0.4
#
# P A = P A|B1   *   P B1    +      P A|B2 * P B2
#
#
# (P A - P A|B2 * P B2)/PB1 = P A|B1

# %%
0.6*0.02
# Out:
# 0.012

# %%
 0.4*0.015
# Out:
# 0.006

# %% [markdown]
# We are unsure how to calculate the probability for this one. But our guess is two thirds equal to 66.67% probability. We are guessing by taking the difference between the results above.

# %% [markdown]
# # 2.
# Make a KNN classifier on the IRIS dataset using Python. Make sure to split the dataset into training and
# testing sets.

# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc

# %%
iris = datasets.load_iris()
X = iris.data
y= iris.target
knn = KNeighborsClassifier(n_neighbors=3)


X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, train_size = 0.8, random_state = 5)

knn.fit(X_train,y_train)
y_predicted = knn.predict(X_test)

print(knn.score(X_test,y_predicted))

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_predicted))
print(classification_report(y_test, y_predicted))

print(accuracy_score(y_test, y_predicted))
# Out:
# 1.0
# [[ 8  0  0]
#  [ 0  9  2]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      0.82      0.90        11
#            2       0.85      1.00      0.92        11
#
#     accuracy                           0.93        30
#    macro avg       0.95      0.94      0.94        30
# weighted avg       0.94      0.93      0.93        30
#
# 0.9333333333333333

# %% [markdown]
# As we can see from the code above, we get a 0.93 accuracy score with a training size of 0.8 and 3 neighbors.

# %% [markdown]
# # 3 - 5
# See KNIME workflow to see more details.

# %%
from IPython.display import display, Image

# %%
display(Image(filename='../Images/workflow.png'))

# %% [markdown]
# This is the workflow we ended up with. The top displays the KNN results of irises (task3) as seen below. We didn't know about the scorer node yet so we don't have a confusion matrix on task 3.

# %% [markdown]
# ### Task 3

# %%
display(Image(filename='../Images/task3-iris.png'))

# %% [markdown]
# ### Task 4

# %%
display(Image(filename='../Images/task4-wines-data.png'))

# %%
display(Image(filename='../Images/task4-wines-confusionmatrix.png'))

# %% [markdown]
# These are the data represantation of winequality-red.csv and winequality-white.csv concatenated into one dataset, adding the classifier column stating if the wine is red or white. We also discarded the quality column as we saw it as nominal numeric data, and we didn't need it. The confusion matrix got these results using an 75/25 split with 75 being the training data, and we used 5 neighbors for the KNN model.

# %% [markdown]
# ### Task 5

# %%
display(Image(filename='../Images/task5-wines-naive_bayes-confusionmatrix.png'))

# %%
display(Image(filename='../Images/task5-wines-naive_bayes-ROC_Curve.png'))

# %% [markdown]
# On this task we used the Gaussian Naive Bayes model to classify the same wine data as in task 4, to see the difference in its precisions. Also we found this ROC Curve Node which looks neat, but we arent sure how to read it.

# %% [markdown]
# # 6.

# %% [markdown]
# We pretty much instanly could conclude that the Gaussian Naive Bayes model was more precise then KNN. We aren't sure if you would still choose KNN over Gaussian Naive Bayes in some cases, but based on our results from the wine dataset it would not seem wise.
